# %%
#1

# %%
d={"a":90,"b":23,"c":51,"d":85,"e":76}
print(d)
# Out:
# {'a': 90, 'b': 23, 'c': 51, 'd': 85, 'e': 76}

# %%
#2

# %%
print("marks of a : ",d["a"])
# Out:
# marks of a :  90

# %%
#3

# %%
d["f"]=68
print(d)
# Out:
# {'a': 90, 'b': 23, 'c': 51, 'd': 85, 'e': 76, 'f': 68}

# %%
#4

# %%
d["a"]=99
print(d)
# Out:
# {'a': 99, 'b': 23, 'c': 51, 'd': 85, 'e': 76, 'f': 68}

# %%
#5

# %%
del d["a"]
print(d)
# Out:
# {'b': 23, 'c': 51, 'd': 85, 'e': 76, 'f': 68}

# %%
#6

# %%
k=d.keys()
print(k)
# Out:
# dict_keys(['b', 'c', 'd', 'e', 'f'])

# %%
#7

# %%
k=d.values()
print(k)
# Out:
# dict_values([23, 51, 85, 76, 68])

# %%
#8

# %%
k=d.items()
print(k)
# Out:
# dict_items([('b', 23), ('c', 51), ('d', 85), ('e', 76), ('f', 68)])

# %%
#9

# %%
print("b" in d.keys() )
# Out:
# True

# %%
#10

# %%
print(23 in d.values())
# Out:
# True

# %%
#11

# %%
print(d.get("b"))
# Out:
# 23

# %%
#12

# %%
a={"a":"sale","b":"production","c":"sale","d":"managment"}
print(a)
# Out:
# {'a': 'sale', 'b': 'production', 'c': 'sale', 'd': 'managment'}

# %%
#13

# %%
print(a["a"])
# Out:
# sale

# %%
#14

# %%
a["e"]="production"
print(a)
# Out:
# {'a': 'sale', 'b': 'production', 'c': 'sale', 'd': 'managment', 'e': 'production'}

# %%
#15

# %%
d["a"]="marketing"
print(a)
# Out:
# {'a': 'sale', 'b': 'production', 'c': 'sale', 'd': 'managment', 'e': 'production'}

# %%
#16

# %%
del d["a"]
print(a)
# Out:
# {'a': 'sale', 'b': 'production', 'c': 'sale', 'd': 'managment', 'e': 'production'}

# %%
#17

# %%
b=dict(sorted(a.items()))
print(b)
# Out:
# {'a': 'sale', 'b': 'production', 'c': 'sale', 'd': 'managment', 'e': 'production'}

# %%
#18

# %%
b = dict(sorted(a.items(), key=lambda x: x[1]))
print(b)
# Out:
# {'d': 'managment', 'b': 'production', 'e': 'production', 'a': 'sale', 'c': 'sale'}

# %%
#19

# %%
b=dict(sorted(a.items(),reverse=True))
print(b)
# Out:
# {'e': 'production', 'd': 'managment', 'c': 'sale', 'b': 'production', 'a': 'sale'}

# %%
#20

# %%
b = dict(sorted(a.items(), key=lambda x: x[1],reverse=True))
print(b)
# Out:
# {'a': 'sale', 'c': 'sale', 'b': 'production', 'e': 'production', 'd': 'managment'}

# %%
#21

# %%
t=23
for k,v in d.items():
    if(v==23):
        print(k)
# Out:
# b

# %%
#22

# %%
c=0
for k,v in d.items():
    if(v>80):
        c+=1
print(c)
# Out:
# 1

# %%
#23

# %%
st = {
    "s1": {
        "age": 20,
        "grade": "A",
        "dept": "cs"
    },
    "s2": {
        "age": 21,
        "grade": "B",
        "dept": "it"
    },
    "s3": {
        "age": 19,
        "grade": "A+",
        "dept": "entc"
    }
}

print(st)
# Out:
# {'s1': {'age': 20, 'grade': 'A', 'dept': 'cs'}, 's2': {'age': 21, 'grade': 'B', 'dept': 'it'}, 's3': {'age': 19, 'grade': 'A+', 'dept': 'entc'}}

# %%
#24

# %%
print(st["s1"]["grade"])
# Out:
# A

# %%
#25

# %%
st["s3"]["dept"]="civil"
print(st)
# Out:
# {'s1': {'age': 20, 'grade': 'A', 'dept': 'cs'}, 's2': {'age': 21, 'grade': 'B', 'dept': 'it'}, 's3': {'age': 19, 'grade': 'A+', 'dept': 'civil'}}

# %%
#26

# %%
for k,v in st.items():
    print(k,":",v["grade"])
# Out:
# s1 : A
# s2 : B
# s3 : A+

# %%
#27

# %%
s1={"a":20,"b":30}
s2={"c":40,"d":50}
s1.update(s2)
print(s1)
# Out:
# {'a': 20, 'b': 30, 'c': 40, 'd': 50}

# %%
#28

# %%
s1.clear()
print(s1)
# Out:
# {}

# %%
#29

# %%
d1={"a":20,"b":30}
d2=d1.copy()
d2["d"]=40
print(d2)
# Out:
# {'a': 20, 'b': 30, 'd': 40}

# %%
#30

# %%
s = {}

for i in range(1, 6):
    s[i] = i * i

print(s)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
