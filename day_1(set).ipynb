# %%
#1

# %%
c={"india","nepal","bhutan","usa","uk"}

# %%
print(c)
# Out:
# {'uk', 'india', 'bhutan', 'nepal', 'usa'}

# %%
#2

# %%
c2=c.copy()

# %%
print(c2)
# Out:
# {'uk', 'india', 'bhutan', 'nepal', 'usa'}

# %%
#3

# %%
l=["mango","apple"]
c3=set(l)
print(c3)
# Out:
# {'apple', 'mango'}

# %%
#4

# %%
c.add("uae")

# %%
print(c)
# Out:
# {'uk', 'india', 'bhutan', 'uae', 'nepal', 'usa'}

# %%
#5

# %%
c.update(["spain","japan"])

# %%
print(c)
# Out:
# {'uk', 'japan', 'india', 'spain', 'bhutan', 'uae', 'nepal', 'usa'}

# %%
#6

# %%
c.add("uae")
print(c)
# Out:
# {'uk', 'japan', 'india', 'spain', 'bhutan', 'uae', 'nepal', 'usa'}

# %%
#7

# %%
c.remove("uk")

# %%
print(c)
# Out:
# {'japan', 'india', 'spain', 'bhutan', 'uae', 'nepal', 'usa'}

# %%
#8

# %%
c.discard("nothing")
print(c)
# Out:
# {'japan', 'india', 'spain', 'bhutan', 'uae', 'nepal', 'usa'}

# %%
#9

# %%
a=c.pop()
print("poped element : ",a)
# Out:
# poped element :  japan

# %%
#10

# %%
c.clear()
print(c)
# Out:
# set()

# %%
#11

# %%
c3={1,2,3,4}
c4={3,4,5,6}

# %%
print(c3|c4)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#12

# %%
print(c3&c4)
# Out:
# {3, 4}

# %%
#13

# %%
print(c3-c4)
# Out:
# {1, 2}

# %%
#14

# %%
print(c3^c4)
# Out:
# {1, 2, 5, 6}

# %%
#15

# %%
print(c3.issubset(c4))
# Out:
# False

# %%
#16

# %%
print(c3.issuperset(c4))
# Out:
# False

# %%
#17

# %%
print(c3.isdisjoint(c4))
# Out:
# False

# %%
#18

# %%
print(2 in c3)
# Out:
# True

# %%
#19

# %%
print(2 not in c3)
# Out:
# False

# %%
#20

# %%
print(len(c3))
# Out:
# 4

# %%
#21

# %%
max(c3)
# Out:
# 4

# %%
min(c3)
# Out:
# 1

# %%
#22

# %%
sum(c3)
# Out:
# 10

# %%
#23

# %%
w=sorted(c3)
print(w)
# Out:
# [1, 2, 3, 4]

# %%
#24

# %%
q=sorted(c3,reverse=True)
print(q)
# Out:
# [4, 3, 2, 1]

# %%
#25

# %%
set1={1,1,1}
print("any :",any(set1))
# Out:
# any : True

# %%
#26

# %%
print("all :",all(set1))
# Out:
# all : True

# %%
#27

# %%
s1={1,2,3}
s2=s1.copy()
print(s2)
# Out:
# {1, 2, 3}

# %%
s1.add(4)
print(s1)
print(s2)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3}

# %%
#independent

# %%
#28

# %%
del s1

# %%
print(s1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 print(s1)
#
# NameError: name 's1' is not defined

# %%
#29

# %%
l2=[1,2,2,3,4,5,3,4]
s3=set(l2)
print(s3)
# Out:
# {1, 2, 3, 4, 5}

# %%
#30

# %%
cl1={"aryan","kiran","ravi","sonu"}
cl2={"harsh","ravi","avi","aryan"}

# %%
print("common",cl1&cl2)
print("only in cl1",cl1-cl2)
print("unique",cl1|cl2)
# Out:
# common {'aryan', 'ravi'}
# only in cl1 {'kiran', 'sonu'}
# unique {'avi', 'kiran', 'sonu', 'harsh', 'ravi', 'aryan'}
