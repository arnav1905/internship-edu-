# %%
name=[]
sport=[]

while(True):
    c=input("are want enter another Participant y or n:\n")
    if(c=="y"):
    
        while(True):
            a=input("enter name of Participant :\n")
            name.append(a)
            t=[]
            print("enter sports (**press n after done**)\n")
            while(True):
                b=input()
                if(b!="n"):
                    t.append(b)
                else:
                    break
            sport.append(t)
            break
    if(c=="n"):
        break
print(name)
print(sport)

re=list(zip(name,sport))
print(re)
# Out:
# are want enter another Participant y or n:
#  y
# enter name of Participant :
#  ravi
# enter sports (**press n after done**)
#  cricket
#  football
#  n
# are want enter another Participant y or n:
#  y
# enter name of Participant :
#  neha
# enter sports (**press n after done**)
#  kabaddi
#  khokho
#  n
# are want enter another Participant y or n:
#  y
# enter name of Participant :
#  puja
# enter sports (**press n after done**)
#  basketball
#  cricket
#  n
# are want enter another Participant y or n:
#  n
# ['ravi', 'neha', 'puja']
# [['cricket', 'football'], ['kabaddi', 'khokho'], ['basketball', 'cricket']]
# [('ravi', ['cricket', 'football']), ('neha', ['kabaddi', 'khokho']), ('puja', ['basketball', 'cricket'])]

# %%
for i in range(len(re)):
    if("cricket" in re[i][1] and "football" in re[i][1]):
        print(re[i][0])
# Out:
# ravi

# %%
s=set()
for i in re:
    for j in i[1]:
        s.add(j)
print(s)
# Out:
# {'kabaddi', 'khokho', 'cricket', 'basketball', 'football'}

# %%
x=[]
for i in sport:
    x.extend(i)
#print(x)
m=0
for i in x:
    s=x.count(i)
    if(m<s):
        m=s
s1=set()
for i in x:
    if(x.count(i)==m):
        s1.add(i)
print(s1)
# Out:
# {'cricket'}
