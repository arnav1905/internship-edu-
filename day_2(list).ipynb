# %%
#questions

# %%
#1

# %%
a1=[20,10,30,40,50,60,90,50,70,50]

# %%
print(a1)
# Out:
# [20, 10, 30, 40, 50, 60, 90, 50, 70, 50]

# %%
#2

# %%
a2=[20,21.3,"abd",True]

# %%
for x in a2:
    print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#3

# %%
print("first",a1[0])
# Out:
# first 20

# %%
print("first",a1[-1])
# Out:
# first 50

# %%
q=len(a1)/2
print(a1[int(q)])
# Out:
# 60

# %%
#4

# %%
print(a1[0:3])
# Out:
# [20, 10, 30]

# %%
print(a1[-3::])
# Out:
# [50, 70, 50]

# %%
#5

# %%
a1[1]=99

# %%
print(a1)
# Out:
# [20, 99, 30, 40, 50, 60, 90, 50, 70, 50]

# %%
#6

# %%
a1.append(83)
print(a1)
# Out:
# [20, 99, 30, 40, 50, 60, 90, 50, 70, 50, 83]

# %%
#7

# %%
a1.insert(2,23)
print(a1)
# Out:
# [20, 99, 23, 30, 40, 50, 60, 90, 50, 70, 50, 83]

# %%
#8

# %%
a3=[63,52]
a1.extend(a3)
print(a1)
# Out:
# [20, 99, 23, 30, 40, 50, 60, 90, 50, 70, 50, 83, 63, 52]

# %%
#9

# %%
a1.remove(23)
print(a1)
# Out:
# [20, 99, 30, 40, 50, 60, 90, 50, 70, 50, 83, 63, 52]

# %%
#10

# %%
d=a1.pop(1)
print(d)
# Out:
# 99

# %%
#11

# %%
del a1[0]
print(a1)
# Out:
# [30, 40, 50, 60, 90, 50, 70, 50, 83, 63, 52]

# %%
#12

# %%
a1.clear()
print(a1)
# Out:
# []

# %%
#13

# %%
a1=[20, 99, 30, 40, 50, 60, 90, 50, 70, 50, 83, 63, 52]
print(a1)
print(90 in a1)
# Out:
# [20, 99, 30, 40, 50, 60, 90, 50, 70, 50, 83, 63, 52]
# True

# %%
#14

# %%
a1.index(99)
# Out:
# 1

# %%
#15

# %%
a1.count(50)
# Out:
# 3

# %%
#16

# %%
a1.sort()
print(a1)
# Out:
# [20, 30, 40, 50, 50, 50, 52, 60, 63, 70, 83, 90, 99]

# %%
#17

# %%
a1.sort(reverse=True)
print(a1)
# Out:
# [99, 90, 83, 70, 63, 60, 52, 50, 50, 50, 40, 30, 20]

# %%
#18

# %%
a1.reverse()
print(a1)
# Out:
# [20, 30, 40, 50, 50, 50, 52, 60, 63, 70, 83, 90, 99]

# %%
#19

# %%
a4=[64,29]
a5=a4.copy()
print(a5)
# Out:
# [64, 29]

# %%
a4[0]=96
print(a4)
print(a5)
# Out:
# [96, 29]
# [64, 29]

# %%
if a4==a5:
    print("afee ct")
else:
    print("not")
# Out:
# not

# %%
#20

# %%
print(a1+[222,333])
# Out:
# [20, 30, 40, 50, 50, 50, 52, 60, 63, 70, 83, 90, 99, 222, 333]
